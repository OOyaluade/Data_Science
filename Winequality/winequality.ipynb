# %%
import pandas as pd, numpy as np, matplotlib.style as style, matplotlib.pyplot as plt

# %%
style.use('ggplot')
plt.plot([2,3,6],[10,15,5])
plt.show()
style.use('default')
plt.plot([2,3,6],[10,15,5])
plt.show()

# %%
red_wine = pd.read_csv('winequality-red.csv', sep=';')
red_corr = red_wine.corr()['quality'][:-1]


white_wine = pd.read_csv('winequality-white.csv', sep=';')
white_corr = white_wine.corr()['quality'][:-1]



style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(9, 5))
ax.barh(white_corr.index, white_corr, left=2,height=0.5)
# Assume the rest of the code is written
ax.barh(red_corr.index, red_corr, height=0.5, left=-0.1)
ax.grid(False)
ax.set_xticks([])

ax.set_yticks([])
ax.set_xticklabels([])
ax.set_yticklabels([])
# Assume the rest of the code is written
x_coords = {'Alcohol': 0.82, 'Sulphates': 0.77, 'pH': 0.91,
            'Density': 0.80, 'Total Sulfur Dioxide': 0.59,
            'Free Sulfur Dioxide': 0.6, 'Chlorides': 0.77,
            'Residual Sugar': 0.67, 'Citric Acid': 0.76,
            'Volatile Acidity': 0.67, 'Fixed Acidity': 0.71}
y_coord = 9.8

for y_label, x_coord in x_coords.items():
    ax.text(x_coord, y_coord, y_label)
    y_coord -= 1

ax.axvline(x=.5,ymax=0.9,ymin=0.1,linewidth=1,alpha=.1,color='grey')

ax.axvline(x=1.45,ymax=0.9,ymin=0.1,linewidth=1,alpha=.1,color='grey')
# Assume the rest of the code is written
ax.axhline(-1, color='grey', linewidth=1, alpha=0.5,
          xmin=0.01, xmax=0.32)
ax.axhline(-1, color='grey', linewidth=1, alpha=0.5,
           xmin=0.67, xmax=0.98)
# Assume the rest of the code is written
ax.text(-0.7, -1.7, '-0.5'+ ' '*31 + '+0.5',
        color='grey', alpha=0.5)
ax.text(1.43, -1.7, '-0.5'+ ' '*31 + '+0.5',
        color='grey', )
ax.axhline(11, color='grey', linewidth=1, alpha=0.5,
          xmin=0.01, xmax=0.32)
ax.axhline(11, color='grey', linewidth=1, alpha=0.5,
           xmin=0.67, xmax=0.98)
ax.text(-0.33, 11.2, 'RED WINE', fontweight='bold')
ax.text(1.75, 11.2, 'WHITE WINE', fontweight='bold')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# Load datasets
red_wine = pd.read_csv('winequality-red.csv', sep=';')
red_corr = red_wine.corr()['quality'][:-1]

white_wine = pd.read_csv('winequality-white.csv', sep=';')
white_corr = white_wine.corr()['quality'][:-1]

# Apply FiveThirtyEight style
style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(9, 5))

# Draw bar plots
ax.barh(white_corr.index, white_corr, left=2, height=0.5)
ax.barh(red_corr.index, red_corr, left=-0.1, height=0.5)

# Clean up grid and ticks
ax.grid(False)
ax.set_xticks([])
ax.set_yticks([])
ax.set_yticklabels([])

# Add Y-axis labels manually
x_coords = {
    'Alcohol': 0.82, 'Sulphates': 0.77, 'pH': 0.91,
    'Density': 0.80, 'Total Sulfur Dioxide': 0.59,
    'Free Sulfur Dioxide': 0.6, 'Chlorides': 0.77,
    'Residual Sugar': 0.67, 'Citric Acid': 0.76,
    'Volatile Acidity': 0.67, 'Fixed Acidity': 0.71
}
y_coord = 9.8
for y_label, x_coord in x_coords.items():
    ax.text(x_coord, y_coord, y_label)
    y_coord -= 1

# Vertical dividers
ax.axvline(0.5, c='grey', alpha=0.1, linewidth=1, ymin=0.1, ymax=0.9)
ax.axvline(1.45, c='grey', alpha=0.1, linewidth=1, ymin=0.1, ymax=0.9)

# Add horizontal lines under each bar group (x-axis labels)
ax.axhline(-1, color='grey', linewidth=1, alpha=0.5, xmin=0.01, xmax=0.32)
ax.axhline(-1, color='grey', linewidth=1, alpha=0.5, xmin=0.67, xmax=0.98)

# Simulated x-axis labels
ax.text(-0.7, -1.7, '-0.5' + ' ' * 31 + '+0.5', color='grey', alpha=0.5)
ax.text(1.43, -1.7, '-0.5' + ' ' * 31 + '+0.5', color='grey', alpha=0.5)

# Section titles
ax.axhline(11, color='grey', linewidth=1, alpha=0.5, xmin=0.01, xmax=0.32)
ax.axhline(11, color='grey', linewidth=1, alpha=0.5, xmin=0.67, xmax=0.98)
ax.text(-0.33, 11.2, 'RED WINE', fontweight='bold')
ax.text(1.75, 11.2, 'WHITE WINE', fontweight='bold')

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# Load datasets
red_wine = pd.read_csv('winequality-red.csv', sep=';')
red_corr = red_wine.corr()['quality'][:-1]

white_wine = pd.read_csv('winequality-white.csv', sep=';')
white_corr = white_wine.corr()['quality'][:-1]

# Apply FiveThirtyEight style
style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(9, 5))

# Bar plots: red wine (left), white wine (right)
ax.barh(white_corr.index, white_corr, left=2, height=0.5)
ax.barh(red_corr.index, red_corr, left=-0.1, height=0.5)

# Clean layout
# Clean layout
ax.grid(False)
ax.set_xticks([])
ax.set_xticklabels([])  # <-- This is the missing line
ax.set_yticks([])
ax.set_yticklabels([])


# Add feature names manually
x_coords = {
    'Alcohol': 0.82, 'Sulphates': 0.77, 'pH': 0.91,
    'Density': 0.80, 'Total Sulfur Dioxide': 0.59,
    'Free Sulfur Dioxide': 0.6, 'Chlorides': 0.77,
    'Residual Sugar': 0.67, 'Citric Acid': 0.76,
    'Volatile Acidity': 0.67, 'Fixed Acidity': 0.71
}
y_coord = 9.8
for y_label, x_coord in x_coords.items():
    ax.text(x_coord, y_coord, y_label)
    y_coord -= 1

# Vertical dividers
ax.axvline(0.5, c='grey', alpha=0.1, linewidth=1, ymin=0.1, ymax=0.9)
ax.axvline(1.45, c='grey', alpha=0.1, linewidth=1, ymin=0.1, ymax=0.9)

# Bottom horizontal lines to simulate x-axis for red and white
ax.axhline(-1, color='grey', linewidth=1, alpha=0.5, xmin=0.01, xmax=0.32)
ax.axhline(-1, color='grey', linewidth=1, alpha=0.5, xmin=0.67, xmax=0.98)

# X-axis markers under each bar group
ax.text(-0.7, -1.7, '-0.5' + ' ' * 31 + '+0.5', color='grey', alpha=0.5)
ax.text(1.43, -1.7, '-0.5' + ' ' * 31 + '+0.5', color='grey', alpha=0.5)

# Top group labels
ax.axhline(11, color='grey', linewidth=1, alpha=0.5, xmin=0.01, xmax=0.32)
ax.axhline(11, color='grey', linewidth=1, alpha=0.5, xmin=0.67, xmax=0.98)
ax.text(-0.33, 11.2, 'RED WINE', fontweight='bold')
ax.text(1.75, 11.2, 'WHITE WINE', fontweight='bold')

# Title and subtitle
ax.text(-0.7, 13.5, 'Wine Quality Most Strongly Correlated With Alcohol Level', fontsize=17, fontweight='bold')
ax.text(-0.7, 12.7, 'Correlation values between wine quality and wine properties (alcohol, pH, etc.).')

# Signature bar
ax.text(-0.7, -2.9,'DATAQUEST' + ' '*94 + 'Source: P. Cortez et al.',
        color='#f0f0f0',
        backgroundcolor='#4d4d4d',
        fontsize=12)


# Show the final plot
plt.show()
