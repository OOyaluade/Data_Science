# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns

# %%
housing = pd.read_csv('housing.csv')

# %%
housing.head(5)
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ...  Fence Misc Feature Misc Val Mo Sold  \
# 0   NaN       IR1          Lvl  ...    NaN          NaN        0       5
# 1   NaN       Reg          Lvl  ...  MnPrv          NaN        0       6
# 2   NaN       IR1          Lvl  ...    NaN         Gar2    12500       6
# 3   NaN       Reg          Lvl  ...    NaN          NaN        0       4
# 4   NaN       IR1          Lvl  ...  MnPrv          NaN        0       3
#
#   Yr Sold Sale Type Sale Condition SalePrice           Year            Rooms
# ...

# %%
housing.tail(5)
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      Alley Lot Shape Land Contour  ...  Fence Misc Feature Misc Val Mo Sold  \
# 2925   NaN       IR1          Lvl  ...  GdPrv          NaN        0       3
# 2926   NaN       IR1          Low  ...  MnPrv          NaN        0       6
# 2927   NaN       Reg          Lvl  ...  MnPrv         Shed      700       7
# 2928   NaN       Reg          Lvl  ...    NaN          NaN        0       4
# 2929   NaN       Reg          Lvl  ...    NaN          NaN        0      11
#
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 84 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
housing[['SalePrice','Gr Liv Area','Overall Qual','Garage Area','Rooms']]
# Out:
#       SalePrice  Gr Liv Area  Overall Qual  Garage Area            Rooms
# 0        215000         1656             6        528.0  7 rooms or more
# 1        105000          896             5        730.0  6 rooms or less
# 2        172000         1329             6        312.0  6 rooms or less
# 3        244000         2110             7        522.0  7 rooms or more
# 4        189900         1629             5        482.0  6 rooms or less
# ...         ...          ...           ...          ...              ...
# 2925     142500         1003             6        588.0  6 rooms or less
# 2926     131000          902             5        484.0  6 rooms or less
# 2927     132000          970             5          0.0  6 rooms or less
# 2928     170000         1389             5        418.0  6 rooms or less
# 2929     188000         2000             7        650.0  7 rooms or more
#
# [2930 rows x 5 columns]

# %%
sns.set_theme()
sns.relplot(data=housing,x='Gr Liv Area',y='SalePrice',hue='Overall Qual',palette='RdYlGn',size='Garage Area',sizes=(1,300))
plt.show()

# %%
sns.set_theme()

sns.relplot(data=housing,x='Gr Liv Area',y='SalePrice',hue='Overall Qual',palette='RdYlGn',size='Rooms',sizes=[200,50])
plt.show()

# %%
sns.set_theme()
sns.relplot(data=housing,x='Gr Liv Area',y='SalePrice',hue='Overall Qual',palette='RdYlGn',size='Garage Area',sizes=(1,300),style='Rooms', markers=["*","D"])
plt.show()

# %%
sns.relplot(data=housing, x='Gr Liv Area', y='SalePrice',
            hue='Overall Qual', palette='RdYlGn',
            size='Garage Area', sizes=(1, 300),
            style='Rooms', markers=['*','v'])
plt.show()

# %%
sns.relplot(data=housing, x='Gr Liv Area', y='SalePrice',
            hue='Overall Qual', palette='RdYlGn',
            size='Garage Area', sizes=(1,300),
            style='Rooms', col='Rooms')
plt.show()
